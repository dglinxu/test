# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.sans-serif']='microsoft yahei'

# %%
fig=plt.figure(figsize=(10,10))
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig=plt.figure(figsize=(8,6))
ax1=plt.subplot(2,2,1)
ax2=plt.subplot(2,2,2)
ax3=plt.subplot(2,2,3)
ax3.plot(np.random.randn(20))
ax1.hist(np.random.randn(100),bins=25)
# ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
ax2.scatter(np.arange(50),np.random.randn(50))
plt.subplots_adjust(wspace=0.1,hspace=0.5)

# %%
ax1.hist(np.random.randn(100),bins=20)

# %%
fig=plt.figure()
ax=plt.subplot(1,1,1)
ax.plot(np.random.randn(50).cumsum(),label='line one')
ax.plot(np.random.randn(50).cumsum(),'k--',label='line two')
ax.legend(loc='best')
# ax.set_title('标题栏',fontsize=20,color='r')
plt.title('我是标题')
plt.xlabel('我是X轴',color='r',rotation=0,fontsize=15)
plt.ylabel('我是Y轴',color='g')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '我是Y轴')

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),columns=['A', 'B', 'C', 'D'],index=np.arange(0, 100, 10))
df.plot.barh(title='标题栏',fontsize=16,grid='True')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def test():
    print('我是test')
def demo():
    print('我是demo')
    return test
r=demo()
r()
# Out:
# 我是demo
# 我是test

# %%
def outer(n):
    num=n
    def inner():
        nonlocal num
        num+=1
        return num
    return inner()
outer(6)
# Out:
# 7
